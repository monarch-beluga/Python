# %%
import geemap
import ee

Map = geemap.Map()
Map
# Out:
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/cloud-platform%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=nw6M2hqxxHcdHRV2JgRC_f6WrM60aMonE77YW4Sgdr4&tc=IplbLuZaf0U-vDSjDxdryiWIHwtVbT_Yzd3AgvxOnUc&cc=1KUyEcfI4gA4tevQzXiL6pgopJAvzb0uMnA8Coz8XJ0>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/cloud-platform%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=nw6M2hqxxHcdHRV2JgRC_f6WrM60aMonE77YW4Sgdr4&tc=IplbLuZaf0U-vDSjDxdryiWIHwtVbT_Yzd3AgvxOnUc&cc=1KUyEcfI4gA4tevQzXiL6pgopJAvzb0uMnA8Coz8XJ0</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# ...

# %%
import os

os.chdir(r"D:\Work\安义数据采集\坑塘_水库")

# %%
import geopandas as gpd

gdf = gpd.read_file("坑塘_水库.shp")

shp = geemap.gdf_to_ee(gdf)
Map.addLayer(shp, {}, "shp")

# %%
Map.add_basemap("HYBRID")

# %%
featrues = Map.draw_features

# %%
f = ee.FeatureCollection(featrues)

# %%
gdf1 = geemap.ee_to_gdf(f)

# %%
gdf1

# %%
def polygon_to_coords_str(polygon):
    # 获取外环坐标
    return ";".join([f"{x:.6f},{y:.6f},40" for x, y in polygon.exterior.coords])


gdf1["feature"] = gdf1['geometry'].apply(polygon_to_coords_str)

# %%
print(gdf1["feature"][1])
